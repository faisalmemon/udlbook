# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# Use the preferred installation method
# !python -m pip install mnist1d
# !python -m pip install torch
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from mnist1d) (2.31.0)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from mnist1d) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->mnist1d) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->mnist1d) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->mnist1d) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->mnist1d) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1
# Collecting torch
#   Downloading torch-2.3.1-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Downloading torch-2.3.1-cp311-none-macosx_11_0_arm64.whl (61.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 MB 16.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torch
# Successfully installed torch-2.3.1

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('mps'))
print('Using:', DEVICE)
# Out:
# Using: mps

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.295797, train error 88.22,  test loss 2.298564, test error 89.03
# Epoch   100, train loss 1.853222, train error 69.75,  test loss 1.698107, test error 67.90
# Epoch   200, train loss 1.842226, train error 69.28,  test loss 1.681010, test error 67.25
# Epoch   300, train loss 1.843766, train error 69.68,  test loss 1.683004, test error 67.22
# Epoch   400, train loss 1.844291, train error 69.43,  test loss 1.680803, test error 67.00
# Epoch   500, train loss 1.845416, train error 69.85,  test loss 1.687899, test error 66.32
# Epoch   600, train loss 1.856242, train error 69.95,  test loss 1.694780, test error 67.60
# Epoch   700, train loss 1.852092, train error 69.80,  test loss 1.693670, test error 67.82
# Epoch   800, train loss 1.859844, train error 70.12,  test loss 1.703337, test error 67.05
# Epoch   900, train loss 1.841541, train error 69.30,  test loss 1.683621, test error 67.07
# Training model with   4 hidden variables
# Epoch     0, train loss 2.303739, train error 86.55,  test loss 2.309978, test error 88.03
# Epoch   100, train loss 1.774548, train error 64.45,  test loss 1.607777, test error 63.72
# Epoch   200, train loss 1.752483, train error 63.72,  test loss 1.597254, test error 62.17
# Epoch   300, train loss 1.738277, train error 63.40,  test loss 1.569907, test error 61.97
# Epoch   400, train loss 1.729602, train error 63.10,  test loss 1.572124, test error 61.35
# Epoch   500, train loss 1.731324, train error 62.05,  test loss 1.567333, test error 60.45
# Epoch   600, train loss 1.729990, train error 63.12,  test loss 1.571309, test error 61.08
# Epoch   700, train loss 1.724737, train error 62.67,  test loss 1.565182, test error 60.92
# Epoch   800, train loss 1.725001, train error 62.28,  test loss 1.579108, test error 61.25
# Epoch   900, train loss 1.721349, train error 60.83,  test loss 1.571491, test error 61.03
# Training model with   6 hidden variables
# Epoch     0, train loss 2.271193, train error 86.45,  test loss 2.252264, test error 84.68
# Epoch   100, train loss 1.693314, train error 59.50,  test loss 1.520474, test error 57.28
# Epoch   200, train loss 1.642608, train error 58.03,  test loss 1.468328, test error 56.15
# Epoch   300, train loss 1.619505, train error 57.83,  test loss 1.451008, test error 55.30
# Epoch   400, train loss 1.615822, train error 57.78,  test loss 1.460688, test error 55.55
# Epoch   500, train loss 1.609950, train error 57.17,  test loss 1.464505, test error 55.70
# Epoch   600, train loss 1.604871, train error 56.35,  test loss 1.465378, test error 55.22
# Epoch   700, train loss 1.604488, train error 56.38,  test loss 1.472207, test error 55.20
# Epoch   800, train loss 1.593970, train error 56.28,  test loss 1.472810, test error 55.10
# Epoch   900, train loss 1.594238, train error 56.75,  test loss 1.475442, test error 55.15
# Training model with   8 hidden variables
# Epoch     0, train loss 2.216732, train error 81.62,  test loss 2.201150, test error 80.72
# Epoch   100, train loss 1.568767, train error 55.00,  test loss 1.398044, test error 52.17
# Epoch   200, train loss 1.507913, train error 50.85,  test loss 1.344738, test error 49.55
# Epoch   300, train loss 1.492417, train error 50.42,  test loss 1.334436, test error 48.90
# Epoch   400, train loss 1.484376, train error 50.75,  test loss 1.339864, test error 49.42
# Epoch   500, train loss 1.489646, train error 51.10,  test loss 1.340473, test error 49.50
# Epoch   600, train loss 1.475795, train error 50.40,  test loss 1.335309, test error 49.95
# Epoch   700, train loss 1.477517, train error 50.72,  test loss 1.339498, test error 50.20
# Epoch   800, train loss 1.472215, train error 50.55,  test loss 1.340683, test error 49.88
# Epoch   900, train loss 1.469603, train error 50.88,  test loss 1.334593, test error 49.75
# Training model with  10 hidden variables
# Epoch     0, train loss 2.248897, train error 84.78,  test loss 2.238488, test error 84.80
# Epoch   100, train loss 1.566098, train error 54.47,  test loss 1.410417, test error 54.20
# Epoch   200, train loss 1.516634, train error 53.47,  test loss 1.387729, test error 53.88
# Epoch   300, train loss 1.490701, train error 51.85,  test loss 1.387681, test error 54.35
# Epoch   400, train loss 1.481851, train error 51.62,  test loss 1.406124, test error 54.28
# Epoch   500, train loss 1.472709, train error 51.03,  test loss 1.412914, test error 54.85
# Epoch   600, train loss 1.464084, train error 50.92,  test loss 1.418049, test error 54.47
# Epoch   700, train loss 1.459232, train error 51.38,  test loss 1.435895, test error 54.88
# Epoch   800, train loss 1.451241, train error 50.40,  test loss 1.450566, test error 54.70
# Epoch   900, train loss 1.451997, train error 50.05,  test loss 1.461293, test error 55.62
# Training model with  14 hidden variables
# Epoch     0, train loss 2.276827, train error 85.22,  test loss 2.263832, test error 85.45
# Epoch   100, train loss 1.491363, train error 51.28,  test loss 1.435990, test error 55.28
# Epoch   200, train loss 1.387868, train error 47.62,  test loss 1.391981, test error 52.25
# Epoch   300, train loss 1.362642, train error 47.35,  test loss 1.401181, test error 52.67
# Epoch   400, train loss 1.333097, train error 45.83,  test loss 1.403073, test error 52.05
# Epoch   500, train loss 1.335796, train error 46.05,  test loss 1.425515, test error 52.03
# Epoch   600, train loss 1.314054, train error 45.35,  test loss 1.435147, test error 52.40
# Epoch   700, train loss 1.317610, train error 45.25,  test loss 1.443823, test error 52.90
# Epoch   800, train loss 1.307650, train error 45.00,  test loss 1.440976, test error 52.35
# Epoch   900, train loss 1.304145, train error 44.80,  test loss 1.457613, test error 52.83
# Training model with  18 hidden variables
# Epoch     0, train loss 2.095450, train error 78.72,  test loss 2.031197, test error 76.57
# Epoch   100, train loss 1.416103, train error 48.45,  test loss 1.426888, test error 53.20
# Epoch   200, train loss 1.330066, train error 45.05,  test loss 1.483574, test error 54.28
# Epoch   300, train loss 1.289718, train error 44.25,  test loss 1.509075, test error 55.08
# Epoch   400, train loss 1.267241, train error 43.53,  test loss 1.552133, test error 55.03
# Epoch   500, train loss 1.234288, train error 42.42,  test loss 1.577870, test error 55.50
# Epoch   600, train loss 1.228011, train error 43.28,  test loss 1.605645, test error 55.38
# Epoch   700, train loss 1.205410, train error 42.33,  test loss 1.626749, test error 55.85
# Epoch   800, train loss 1.203744, train error 42.40,  test loss 1.633518, test error 55.72
# Epoch   900, train loss 1.201289, train error 42.53,  test loss 1.649168, test error 56.00
# Training model with  22 hidden variables
# Epoch     0, train loss 2.154961, train error 80.15,  test loss 2.111061, test error 79.18
# Epoch   100, train loss 1.262837, train error 42.40,  test loss 1.299674, test error 48.58
# Epoch   200, train loss 1.135734, train error 37.75,  test loss 1.339733, test error 48.22
# Epoch   300, train loss 1.081136, train error 36.30,  test loss 1.379897, test error 48.53
# Epoch   400, train loss 1.053260, train error 35.97,  test loss 1.463128, test error 49.40
# Epoch   500, train loss 1.025119, train error 34.57,  test loss 1.515658, test error 50.30
# Epoch   600, train loss 1.005875, train error 33.62,  test loss 1.595283, test error 50.95
# Epoch   700, train loss 0.993393, train error 34.22,  test loss 1.617286, test error 50.17
# Epoch   800, train loss 0.974173, train error 32.55,  test loss 1.699874, test error 50.67
# Epoch   900, train loss 0.969250, train error 32.55,  test loss 1.727685, test error 51.42
# Training model with  26 hidden variables
# Epoch     0, train loss 2.194020, train error 80.80,  test loss 2.172937, test error 79.90
# Epoch   100, train loss 1.182228, train error 38.95,  test loss 1.279429, test error 47.58
# Epoch   200, train loss 1.054019, train error 35.88,  test loss 1.405874, test error 49.50
# Epoch   300, train loss 0.964896, train error 33.20,  test loss 1.540595, test error 50.97
# Epoch   400, train loss 0.906172, train error 31.15,  test loss 1.716815, test error 51.40
# Epoch   500, train loss 0.878022, train error 30.47,  test loss 1.822609, test error 53.28
# Epoch   600, train loss 0.849772, train error 29.30,  test loss 1.923208, test error 53.65
# Epoch   700, train loss 0.836247, train error 28.50,  test loss 2.015085, test error 53.80
# Epoch   800, train loss 0.824346, train error 28.78,  test loss 2.054236, test error 53.67
# Epoch   900, train loss 0.814997, train error 29.12,  test loss 2.124636, test error 53.65
# Training model with  30 hidden variables
# Epoch     0, train loss 2.106814, train error 78.07,  test loss 2.070697, test error 77.85
# Epoch   100, train loss 1.038983, train error 33.97,  test loss 1.280568, test error 47.47
# Epoch   200, train loss 0.853992, train error 27.43,  test loss 1.449005, test error 47.83
# Epoch   300, train loss 0.778012, train error 24.90,  test loss 1.624415, test error 49.08
# Epoch   400, train loss 0.746645, train error 23.82,  test loss 1.806467, test error 50.97
# Epoch   500, train loss 0.711764, train error 24.18,  test loss 1.969730, test error 52.42
# Epoch   600, train loss 0.688947, train error 23.30,  test loss 2.060277, test error 52.22
# Epoch   700, train loss 0.714134, train error 24.07,  test loss 2.193959, test error 53.65
# Epoch   800, train loss 0.672213, train error 22.32,  test loss 2.153267, test error 52.00
# Epoch   900, train loss 0.666544, train error 22.40,  test loss 2.250447, test error 52.50
# Training model with  35 hidden variables
# Epoch     0, train loss 2.148540, train error 79.68,  test loss 2.112488, test error 78.90
# Epoch   100, train loss 1.024126, train error 32.90,  test loss 1.347198, test error 48.33
# Epoch   200, train loss 0.824470, train error 27.20,  test loss 1.686542, test error 51.90
# Epoch   300, train loss 0.697809, train error 23.07,  test loss 1.999778, test error 51.88
# Epoch   400, train loss 0.600757, train error 19.05,  test loss 2.355706, test error 53.42
# Epoch   500, train loss 0.550499, train error 17.85,  test loss 2.692843, test error 54.50
# Epoch   600, train loss 0.512349, train error 16.68,  test loss 2.988991, test error 55.15
# Epoch   700, train loss 0.510441, train error 16.93,  test loss 3.362180, test error 56.53
# Epoch   800, train loss 0.475209, train error 15.62,  test loss 3.620956, test error 56.62
# Epoch   900, train loss 0.458072, train error 14.82,  test loss 3.920756, test error 57.40
# Training model with  40 hidden variables
# Epoch     0, train loss 2.174078, train error 80.70,  test loss 2.154047, test error 80.47
# Epoch   100, train loss 0.940667, train error 31.12,  test loss 1.383963, test error 48.03
# Epoch   200, train loss 0.673515, train error 21.70,  test loss 1.827530, test error 51.75
# Epoch   300, train loss 0.539739, train error 18.00,  test loss 2.454845, test error 53.90
# Epoch   400, train loss 0.427518, train error 13.88,  test loss 3.063119, test error 54.33
# Epoch   500, train loss 0.363187, train error 11.88,  test loss 3.709671, test error 54.88
# Epoch   600, train loss 0.349780, train error 11.97,  test loss 4.415221, test error 55.10
# Epoch   700, train loss 0.268755, train error 9.00,  test loss 4.992827, test error 55.83
# Epoch   800, train loss 0.287369, train error 10.57,  test loss 5.794315, test error 56.85
# Epoch   900, train loss 0.218588, train error 7.70,  test loss 6.411088, test error 56.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.047755, train error 75.68,  test loss 1.995628, test error 76.18
# Epoch   100, train loss 0.809333, train error 25.22,  test loss 1.446622, test error 49.70
# Epoch   200, train loss 0.480388, train error 15.45,  test loss 2.180841, test error 52.95
# Epoch   300, train loss 0.296915, train error 8.68,  test loss 3.209896, test error 54.40
# Epoch   400, train loss 0.245044, train error 8.53,  test loss 4.383185, test error 55.30
# Epoch   500, train loss 0.195746, train error 6.88,  test loss 5.713898, test error 55.33
# Epoch   600, train loss 0.084236, train error 2.20,  test loss 6.920762, test error 55.35
# Epoch   700, train loss 0.012689, train error 0.00,  test loss 7.860355, test error 54.97
# Epoch   800, train loss 0.008545, train error 0.00,  test loss 8.491630, test error 55.28
# Epoch   900, train loss 0.006473, train error 0.00,  test loss 8.973698, test error 55.35
# Training model with  50 hidden variables
# Epoch     0, train loss 2.088361, train error 77.12,  test loss 2.050081, test error 77.38
# Epoch   100, train loss 0.703689, train error 22.68,  test loss 1.614146, test error 51.90
# Epoch   200, train loss 0.328064, train error 9.18,  test loss 2.668390, test error 54.17
# Epoch   300, train loss 0.132017, train error 2.85,  test loss 4.281352, test error 55.70
# Epoch   400, train loss 0.025294, train error 0.00,  test loss 5.781444, test error 55.65
# Epoch   500, train loss 0.012558, train error 0.00,  test loss 6.684058, test error 55.75
# Epoch   600, train loss 0.008148, train error 0.00,  test loss 7.290696, test error 55.67
# Epoch   700, train loss 0.005896, train error 0.00,  test loss 7.746758, test error 55.80
# Epoch   800, train loss 0.004570, train error 0.00,  test loss 8.113355, test error 55.78
# Epoch   900, train loss 0.003730, train error 0.00,  test loss 8.427155, test error 55.88
# Training model with  55 hidden variables
# Epoch     0, train loss 2.057048, train error 76.28,  test loss 2.017783, test error 75.85
# Epoch   100, train loss 0.601791, train error 17.97,  test loss 1.714651, test error 51.15
# Epoch   200, train loss 0.202509, train error 4.40,  test loss 3.181965, test error 54.95
# Epoch   300, train loss 0.033259, train error 0.00,  test loss 4.929865, test error 55.25
# Epoch   400, train loss 0.013096, train error 0.00,  test loss 5.923683, test error 55.62
# Epoch   500, train loss 0.007780, train error 0.00,  test loss 6.538299, test error 55.97
# Epoch   600, train loss 0.005357, train error 0.00,  test loss 6.982285, test error 55.92
# Epoch   700, train loss 0.004064, train error 0.00,  test loss 7.322903, test error 55.97
# Epoch   800, train loss 0.003223, train error 0.00,  test loss 7.606594, test error 56.28
# Epoch   900, train loss 0.002661, train error 0.00,  test loss 7.846447, test error 56.28
# Training model with  60 hidden variables
# Epoch     0, train loss 2.070708, train error 76.88,  test loss 2.031136, test error 77.62
# Epoch   100, train loss 0.510520, train error 15.12,  test loss 1.738182, test error 51.08
# Epoch   200, train loss 0.088668, train error 0.50,  test loss 3.280759, test error 52.40
# Epoch   300, train loss 0.018949, train error 0.00,  test loss 4.527514, test error 53.65
# Epoch   400, train loss 0.009529, train error 0.00,  test loss 5.174932, test error 53.92
# Epoch   500, train loss 0.006042, train error 0.00,  test loss 5.595047, test error 54.20
# Epoch   600, train loss 0.004371, train error 0.00,  test loss 5.923723, test error 54.17
# Epoch   700, train loss 0.003343, train error 0.00,  test loss 6.176782, test error 54.20
# Epoch   800, train loss 0.002689, train error 0.00,  test loss 6.385700, test error 54.20
# Epoch   900, train loss 0.002241, train error 0.00,  test loss 6.565802, test error 54.28
# Training model with  70 hidden variables
# Epoch     0, train loss 2.022156, train error 75.72,  test loss 1.959854, test error 73.93
# Epoch   100, train loss 0.345357, train error 8.22,  test loss 1.924345, test error 50.92
# Epoch   200, train loss 0.032160, train error 0.00,  test loss 3.524670, test error 52.78
# Epoch   300, train loss 0.010953, train error 0.00,  test loss 4.278587, test error 53.08
# Epoch   400, train loss 0.006016, train error 0.00,  test loss 4.695671, test error 52.83
# Epoch   500, train loss 0.004036, train error 0.00,  test loss 4.991591, test error 52.88
# Epoch   600, train loss 0.002993, train error 0.00,  test loss 5.216180, test error 52.90
# Epoch   700, train loss 0.002352, train error 0.00,  test loss 5.397792, test error 52.65
# Epoch   800, train loss 0.001922, train error 0.00,  test loss 5.549327, test error 52.80
# Epoch   900, train loss 0.001616, train error 0.00,  test loss 5.681319, test error 52.78
# Training model with  80 hidden variables
# Epoch     0, train loss 2.050374, train error 75.30,  test loss 2.031376, test error 76.28
# Epoch   100, train loss 0.208559, train error 3.03,  test loss 2.052537, test error 50.22
# Epoch   200, train loss 0.019155, train error 0.00,  test loss 3.344125, test error 51.12
# Epoch   300, train loss 0.007860, train error 0.00,  test loss 3.868932, test error 51.20
# Epoch   400, train loss 0.004649, train error 0.00,  test loss 4.187022, test error 51.45
# Epoch   500, train loss 0.003216, train error 0.00,  test loss 4.411962, test error 51.67
# Epoch   600, train loss 0.002425, train error 0.00,  test loss 4.586461, test error 51.62
# Epoch   700, train loss 0.001930, train error 0.00,  test loss 4.730059, test error 51.62
# Epoch   800, train loss 0.001589, train error 0.00,  test loss 4.851703, test error 51.62
# Epoch   900, train loss 0.001345, train error 0.00,  test loss 4.956549, test error 51.62
# Training model with  90 hidden variables
# Epoch     0, train loss 1.979905, train error 72.50,  test loss 1.910607, test error 72.50
# Epoch   100, train loss 0.146436, train error 1.22,  test loss 2.173537, test error 50.95
# Epoch   200, train loss 0.015008, train error 0.00,  test loss 3.265616, test error 51.62
# Epoch   300, train loss 0.006586, train error 0.00,  test loss 3.709362, test error 51.70
# Epoch   400, train loss 0.004026, train error 0.00,  test loss 3.980296, test error 51.83
# Epoch   500, train loss 0.002830, train error 0.00,  test loss 4.175673, test error 52.08
# Epoch   600, train loss 0.002150, train error 0.00,  test loss 4.331232, test error 52.17
# Epoch   700, train loss 0.001720, train error 0.00,  test loss 4.456080, test error 52.15
# Epoch   800, train loss 0.001424, train error 0.00,  test loss 4.562818, test error 52.25
# Epoch   900, train loss 0.001210, train error 0.00,  test loss 4.655923, test error 52.30
# Training model with 100 hidden variables
# Epoch     0, train loss 2.023508, train error 75.43,  test loss 1.971121, test error 76.30
# Epoch   100, train loss 0.098929, train error 0.45,  test loss 2.258731, test error 52.05
# Epoch   200, train loss 0.012550, train error 0.00,  test loss 3.129934, test error 51.90
# Epoch   300, train loss 0.005850, train error 0.00,  test loss 3.505093, test error 52.08
# Epoch   400, train loss 0.003603, train error 0.00,  test loss 3.744509, test error 52.35
# Epoch   500, train loss 0.002554, train error 0.00,  test loss 3.915587, test error 52.35
# Epoch   600, train loss 0.001955, train error 0.00,  test loss 4.053867, test error 52.45
# Epoch   700, train loss 0.001568, train error 0.00,  test loss 4.162742, test error 52.40
# Epoch   800, train loss 0.001303, train error 0.00,  test loss 4.258336, test error 52.42
# Epoch   900, train loss 0.001109, train error 0.00,  test loss 4.338866, test error 52.40
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980754, train error 73.57,  test loss 1.896246, test error 73.68
# Epoch   100, train loss 0.051401, train error 0.00,  test loss 2.251933, test error 49.80
# Epoch   200, train loss 0.009568, train error 0.00,  test loss 2.838241, test error 49.88
# Epoch   300, train loss 0.004717, train error 0.00,  test loss 3.115778, test error 50.05
# Epoch   400, train loss 0.003017, train error 0.00,  test loss 3.291472, test error 50.05
# Epoch   500, train loss 0.002176, train error 0.00,  test loss 3.423570, test error 50.12
# Epoch   600, train loss 0.001682, train error 0.00,  test loss 3.527801, test error 50.05
# Epoch   700, train loss 0.001360, train error 0.00,  test loss 3.614152, test error 50.05
# Epoch   800, train loss 0.001135, train error 0.00,  test loss 3.687865, test error 50.12
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.751400, test error 50.00
# Training model with 140 hidden variables
# Epoch     0, train loss 1.935884, train error 71.85,  test loss 1.874041, test error 73.32
# Epoch   100, train loss 0.035335, train error 0.00,  test loss 2.309060, test error 51.62
# Epoch   200, train loss 0.008050, train error 0.00,  test loss 2.832603, test error 51.90
# Epoch   300, train loss 0.004127, train error 0.00,  test loss 3.083824, test error 51.75
# Epoch   400, train loss 0.002673, train error 0.00,  test loss 3.245300, test error 51.75
# Epoch   500, train loss 0.001945, train error 0.00,  test loss 3.367163, test error 51.83
# Epoch   600, train loss 0.001510, train error 0.00,  test loss 3.463782, test error 51.95
# Epoch   700, train loss 0.001226, train error 0.00,  test loss 3.544431, test error 51.85
# Epoch   800, train loss 0.001026, train error 0.00,  test loss 3.612327, test error 51.85
# Epoch   900, train loss 0.000879, train error 0.00,  test loss 3.672107, test error 51.85
# Training model with 160 hidden variables
# Epoch     0, train loss 1.954150, train error 71.93,  test loss 1.892024, test error 72.78
# Epoch   100, train loss 0.028091, train error 0.00,  test loss 2.106374, test error 48.95
# Epoch   200, train loss 0.007112, train error 0.00,  test loss 2.513532, test error 49.42
# Epoch   300, train loss 0.003739, train error 0.00,  test loss 2.707869, test error 49.28
# Epoch   400, train loss 0.002461, train error 0.00,  test loss 2.836801, test error 49.28
# Epoch   500, train loss 0.001802, train error 0.00,  test loss 2.935097, test error 49.15
# Epoch   600, train loss 0.001407, train error 0.00,  test loss 3.013391, test error 49.20
# Epoch   700, train loss 0.001146, train error 0.00,  test loss 3.078287, test error 49.30
# Epoch   800, train loss 0.000962, train error 0.00,  test loss 3.134223, test error 49.33
# Epoch   900, train loss 0.000826, train error 0.00,  test loss 3.183322, test error 49.28
# Training model with 180 hidden variables
# Epoch     0, train loss 1.947181, train error 71.12,  test loss 1.869644, test error 72.85
# Epoch   100, train loss 0.024095, train error 0.00,  test loss 2.021174, test error 48.25
# Epoch   200, train loss 0.006628, train error 0.00,  test loss 2.364230, test error 47.97
# Epoch   300, train loss 0.003544, train error 0.00,  test loss 2.537258, test error 48.08
# Epoch   400, train loss 0.002352, train error 0.00,  test loss 2.653188, test error 48.05
# Epoch   500, train loss 0.001731, train error 0.00,  test loss 2.740253, test error 48.10
# Epoch   600, train loss 0.001356, train error 0.00,  test loss 2.810173, test error 47.97
# Epoch   700, train loss 0.001107, train error 0.00,  test loss 2.868943, test error 47.78
# Epoch   800, train loss 0.000931, train error 0.00,  test loss 2.918692, test error 47.92
# Epoch   900, train loss 0.000800, train error 0.00,  test loss 2.962213, test error 47.90
# Training model with 200 hidden variables
# Epoch     0, train loss 1.936528, train error 71.62,  test loss 1.856007, test error 71.05
# Epoch   100, train loss 0.022201, train error 0.00,  test loss 1.980773, test error 47.95
# Epoch   200, train loss 0.006258, train error 0.00,  test loss 2.304576, test error 48.20
# Epoch   300, train loss 0.003381, train error 0.00,  test loss 2.468836, test error 48.15
# Epoch   400, train loss 0.002253, train error 0.00,  test loss 2.580684, test error 48.28
# Epoch   500, train loss 0.001664, train error 0.00,  test loss 2.664833, test error 48.22
# Epoch   600, train loss 0.001307, train error 0.00,  test loss 2.732266, test error 48.15
# Epoch   700, train loss 0.001069, train error 0.00,  test loss 2.787886, test error 48.22
# Epoch   800, train loss 0.000900, train error 0.00,  test loss 2.835971, test error 48.17
# Epoch   900, train loss 0.000775, train error 0.00,  test loss 2.878449, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.931368, train error 71.20,  test loss 1.854155, test error 71.95
# Epoch   100, train loss 0.017344, train error 0.00,  test loss 1.915304, test error 47.12
# Epoch   200, train loss 0.005386, train error 0.00,  test loss 2.169315, test error 46.72
# Epoch   300, train loss 0.002999, train error 0.00,  test loss 2.306597, test error 46.75
# Epoch   400, train loss 0.002023, train error 0.00,  test loss 2.399719, test error 46.67
# Epoch   500, train loss 0.001505, train error 0.00,  test loss 2.470716, test error 46.78
# Epoch   600, train loss 0.001188, train error 0.00,  test loss 2.528099, test error 46.95
# Epoch   700, train loss 0.000975, train error 0.00,  test loss 2.576081, test error 46.83
# Epoch   800, train loss 0.000823, train error 0.00,  test loss 2.617129, test error 46.75
# Epoch   900, train loss 0.000710, train error 0.00,  test loss 2.653100, test error 46.78
# Training model with 300 hidden variables
# Epoch     0, train loss 1.861725, train error 67.10,  test loss 1.783581, test error 68.62
# Epoch   100, train loss 0.014253, train error 0.00,  test loss 1.845595, test error 46.42
# Epoch   200, train loss 0.004765, train error 0.00,  test loss 2.064698, test error 46.65
# Epoch   300, train loss 0.002706, train error 0.00,  test loss 2.180461, test error 46.40
# Epoch   400, train loss 0.001843, train error 0.00,  test loss 2.263873, test error 46.50
# Epoch   500, train loss 0.001380, train error 0.00,  test loss 2.325480, test error 46.55
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.375557, test error 46.53
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.417227, test error 46.50
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.453485, test error 46.50
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.485248, test error 46.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.859920, train error 67.20,  test loss 1.771428, test error 68.50
# Epoch   100, train loss 0.011796, train error 0.00,  test loss 1.741961, test error 44.78
# Epoch   200, train loss 0.004191, train error 0.00,  test loss 1.921676, test error 44.83
# Epoch   300, train loss 0.002427, train error 0.00,  test loss 2.019590, test error 44.88
# Epoch   400, train loss 0.001671, train error 0.00,  test loss 2.087929, test error 44.95
# Epoch   500, train loss 0.001258, train error 0.00,  test loss 2.141359, test error 44.92
# Epoch   600, train loss 0.001001, train error 0.00,  test loss 2.183883, test error 44.92
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.219802, test error 45.00
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.250719, test error 45.03
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.278006, test error 44.92

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
